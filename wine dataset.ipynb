# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("wine.csv")
df.head()
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315  Proline
# 0             5.64  1.04         3.92     1065
# 1             4.38  1.05         3.40     1050
# ...

# %%
df.dtypes
# Out:
# Class                     int64
# Alcohol                 float64
# Malic acid              float64
# Ash                     float64
# Alcalinity of ash       float64
# Magnesium                 int64
# Total phenols           float64
# Flavanoids              float64
# Nonflavanoid phenols    float64
# Proanthocyanins         float64
# Color intensity         float64
# Hue                     float64
# OD280/OD315             float64
# Proline                   int64
# dtype: object

# %%
df.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
# Checking for missing values

df.isnull().sum()
# Out:
# Class                   0
# Alcohol                 0
# Malic acid              0
# Ash                     0
# Alcalinity of ash       0
# Magnesium               0
# Total phenols           0
# Flavanoids              0
# Nonflavanoid phenols    0
# Proanthocyanins         0
# Color intensity         0
# Hue                     0
# OD280/OD315             0
# Proline                 0
# dtype: int64

# %%
# Using heatmap 

import seaborn as sns
sns.heatmap(df.isnull(),annot=True)

# %%
# There are no missing values

# %%
# Correlation

df.corr()
# Out:
#                          Class   Alcohol  Malic acid       Ash  \
# Class                 1.000000 -0.328222    0.437776 -0.049643
# Alcohol              -0.328222  1.000000    0.094397  0.211545
# Malic acid            0.437776  0.094397    1.000000  0.164045
# Ash                  -0.049643  0.211545    0.164045  1.000000
# Alcalinity of ash     0.517859 -0.310235    0.288500  0.443367
# Magnesium            -0.209179  0.270798   -0.054575  0.286587
# Total phenols        -0.719163  0.289101   -0.335167  0.128980
# Flavanoids           -0.847498  0.236815   -0.411007  0.115077
# Nonflavanoid phenols  0.489109 -0.155929    0.292977  0.186230
# Proanthocyanins      -0.499130  0.136698   -0.220746  0.009652
# Color intensity       0.265668  0.546364    0.248985  0.258887
# Hue                  -0.617369 -0.071747   -0.561296 -0.074667
# OD280/OD315          -0.788230  0.072343   -0.368710  0.003911
# Proline              -0.633717  0.643720   -0.192011  0.223626
#
# ...

# %%
# Visualizing correlation using heatmap

import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
plt.title("Correlation")
sns.heatmap(df.corr(),annot=True,cmap='Reds')

# %%
# here Flavanoids has high +ve correlation with Total phenols,OD280/OD315 and Proanthocyanins and hence can be dropped
# The column Ash has very low -ve correlation with the target Class and hence can also be dropped

df.drop("Ash",axis=1,inplace=True)
df.drop("Flavanoids",axis=1,inplace=True)

# %%
df.head()
# Out:
#    Class  Alcohol  Malic acid  Alcalinity of ash  Magnesium  Total phenols  \
# 0      1    14.23        1.71               15.6        127           2.80
# 1      1    13.20        1.78               11.2        100           2.65
# 2      1    13.16        2.36               18.6        101           2.80
# 3      1    14.37        1.95               16.8        113           3.85
# 4      1    13.24        2.59               21.0        118           2.80
#
#    Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  OD280/OD315  \
# 0                  0.28             2.29             5.64  1.04         3.92
# 1                  0.26             1.28             4.38  1.05         3.40
# 2                  0.30             2.81             5.68  1.03         3.17
# 3                  0.24             2.18             7.80  0.86         3.45
# 4                  0.39             1.82             4.32  1.04         2.93
#
#    Proline
# 0     1065
# 1     1050
# 2     1185
# ...

# %%
sns.pairplot(df,hue="Class")

# %%
# Checking for outliers using boxplot

collist = df.columns.values
ncol = 12
nrows = 5

plt.figure(figsize=(ncol,5*ncol))
for i in range(len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],orient = "v")
    plt.tight_layout()

# %%
# Removing outliers

from scipy.stats import zscore
z=np.abs(zscore(df))
df_new=df[(z<3).all(axis=1)]
df_new.head()
# Out:
#    Class  Alcohol  Malic acid  Alcalinity of ash  Magnesium  Total phenols  \
# 0      1    14.23        1.71               15.6        127           2.80
# 1      1    13.20        1.78               11.2        100           2.65
# 2      1    13.16        2.36               18.6        101           2.80
# 3      1    14.37        1.95               16.8        113           3.85
# 4      1    13.24        2.59               21.0        118           2.80
#
#    Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  OD280/OD315  \
# 0                  0.28             2.29             5.64  1.04         3.92
# 1                  0.26             1.28             4.38  1.05         3.40
# 2                  0.30             2.81             5.68  1.03         3.17
# 3                  0.24             2.18             7.80  0.86         3.45
# 4                  0.39             1.82             4.32  1.04         2.93
#
#    Proline
# 0     1065
# 1     1050
# 2     1185
# ...

# %%
df.shape
# Out:
# (178, 12)

# %%
df_new.shape
# Out:
# (171, 12)

# %%
df = df_new

# %%
# Skewness

df.skew()
# Out:
# Class                   0.124758
# Alcohol                -0.021204
# Malic acid              0.978996
# Alcalinity of ash       0.102736
# Magnesium               0.554190
# Total phenols           0.121218
# Nonflavanoid phenols    0.464734
# Proanthocyanins         0.307440
# Color intensity         0.733954
# Hue                    -0.154560
# OD280/OD315            -0.280195
# Proline                 0.760078
# dtype: float64

# %%
# Visualizing skewness

collist = df.columns.values
ncol = 6
nrow= 5

plt.figure(figsize = (16,16))
plt.title("Skewness")
for i in range(len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.distplot(df[collist[i]])

# %%
# Using log transform to treat skewness

for col in df[['Malic acid','Magnesium','Color intensity','Proline']]:
    df[col]=np.log(df[col])

# %%
df.skew()
# Out:
# Class                   0.124758
# Alcohol                -0.021204
# Malic acid              0.226152
# Alcalinity of ash       0.102736
# Magnesium               0.256017
# Total phenols           0.121218
# Nonflavanoid phenols    0.464734
# Proanthocyanins         0.307440
# Color intensity        -0.168830
# Hue                    -0.154560
# OD280/OD315            -0.280195
# Proline                 0.085012
# dtype: float64

# %%
# Splitting independent variables and target

x = df.drop('Class',axis=1)
print(x.head())
y = df[['Class']]
print("\n")
print(y.head())
# Out:
#    Alcohol  Malic acid  Alcalinity of ash  Magnesium  Total phenols  \
# 0    14.23    0.536493               15.6   4.844187           2.80
# 1    13.20    0.576613               11.2   4.605170           2.65
# 2    13.16    0.858662               18.6   4.615121           2.80
# 3    14.37    0.667829               16.8   4.727388           3.85
# 4    13.24    0.951658               21.0   4.770685           2.80
#
#    Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  OD280/OD315  \
# 0                  0.28             2.29         1.729884  1.04         3.92
# 1                  0.26             1.28         1.477049  1.05         3.40
# 2                  0.30             2.81         1.736951  1.03         3.17
# 3                  0.24             2.18         2.054124  0.86         3.45
# 4                  0.39             1.82         1.463255  1.04         2.93
#
#     Proline
# 0  6.970730
# 1  6.956545
# 2  7.077498
# 3  7.299797
# 4  6.599870
#
#
# ...

# %%
# Using Standard scaler for uniform range in all columns

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x = sc.fit_transform(x)
x = pd.DataFrame(x)
x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.524173 -0.469873 -1.164940  2.044067  0.832121 -0.677410  1.390638
# 1  0.225858 -0.379742 -2.515065  0.144830  0.592248 -0.839761 -0.508746
# 2  0.175438  0.253888 -0.244401  0.223896  0.832121 -0.515060  2.368539
# 3  1.700643 -0.174823 -0.796724  1.115976  2.511233 -1.002112  1.183775
# 4  0.276278  0.462807  0.492031  1.460014  0.832121  0.215518  0.506766
#
#           7         8         9        10
# 0  0.443580  0.399451  1.843172  1.049676
# 1 -0.119829  0.445220  1.115979  1.015586
# 2  0.459328  0.353681  0.794335  1.306276
# 3  1.166105 -0.424396  1.185901  1.840537
# 4 -0.150566  0.399451  0.458708  0.158374

# %%
x.skew()
# Out:
# 0    -0.021204
# 1     0.226152
# 2     0.102736
# 3     0.256017
# 4     0.121218
# 5     0.464734
# 6     0.307440
# 7    -0.168830
# 8    -0.154560
# 9    -0.280195
# 10    0.085012
# dtype: float64

# %%
# Splitting into training and testing data

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=62)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %%
model = [GaussianNB(),SVC(),DecisionTreeClassifier(),KNeighborsClassifier()]

for m in model:
    m.fit(x_train,y_train)
    print(m.score(x_train,y_train))
    predm=m.predict(x_test)
    print("accuracy score of", m,"is")
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print("\n")
# Out:
# 0.9852941176470589
# accuracy score of GaussianNB() is
# 1.0
# [[ 9  0  0]
#  [ 0 16  0]
#  [ 0  0 10]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        16
#            3       1.00      1.00      1.00        10
#
#     accuracy                           1.00        35
#    macro avg       1.00      1.00      1.00        35
# weighted avg       1.00      1.00      1.00        35
#
#
#
# 0.9926470588235294
# accuracy score of SVC() is
# 0.9714285714285714
# [[ 9  0  0]
#  [ 0 15  1]
#  [ 0  0 10]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         9
#            2       1.00      0.94      0.97        16
#            3       0.91      1.00      0.95        10
#
#     accuracy                           0.97        35
#    macro avg       0.97      0.98      0.97        35
# ...

# %%
from sklearn.model_selection import cross_val_score

for m in model:
    print("For",m ,cross_val_score(m,x,y,cv=10).mean())
# Out:
# For GaussianNB() 0.9767973856209149
# For SVC() 0.9826797385620916
# For DecisionTreeClassifier() 0.8892156862745099
# For KNeighborsClassifier() 0.9653594771241829

# %%
# Saving the model - GuassianNB

import joblib

joblib.dump(GaussianNB(),"gnb_wine.pkl")
# Out:
# ['gnb_wine.pkl']
